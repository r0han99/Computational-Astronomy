# %%
import pandas as pd

# %%
! ls Exo-Planet-Archive/PSCompPars_2022.12.02_18.47.14.csv
# Out:
# Crossmatching                         Pulsars
# Exo-Planet-Archive                    README.md
# Galaxy-Classification                 data-remapping.ipynb
# Galaxy-Classification-Neural-Networks

# %%
data = pd.read_csv('./Exo-Planet-Archive/all_exoplanets_2021.csv')
data
# Out:
#        No. Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 0        1    11 Com b      11 Com          2            1  Radial Velocity
# 1        2    11 UMi b      11 UMi          1            1  Radial Velocity
# 2        3    14 And b      14 And          1            1  Radial Velocity
# 3        4    14 Her b      14 Her          1            2  Radial Velocity
# 4        5  16 Cyg B b    16 Cyg B          3            1  Radial Velocity
# ...    ...         ...         ...        ...          ...              ...
# 4570  4571   tau Gem b     tau Gem          1            1  Radial Velocity
# 4571  4572   ups And b     ups And          2            3  Radial Velocity
# 4572  4573   ups And c     ups And          2            3  Radial Velocity
# 4573  4574   ups And d     ups And          2            3  Radial Velocity
# 4574  4575    xi Aql b      xi Aql          1            1  Radial Velocity
#
# ...

# %%
data = pd.read_csv('./Exo-Planet-Archive/PS_data.csv',skiprows=49)
data.columns
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbsmax', 'pl_rade',
#        'pl_radj', 'pl_bmasse', 'pl_bmassj', 'pl_bmassprov', 'pl_orbeccen',
#        'pl_insol', 'pl_eqt', 'ttv_flag', 'st_refname', 'st_spectype',
#        'st_teff', 'st_rad', 'st_mass', 'st_met', 'st_metratio', 'st_logg',
#        'sy_refname', 'rastr', 'ra', 'decstr', 'dec', 'sy_dist', 'sy_vmag',
#        'sy_kmag', 'sy_gaiamag', 'rowupdate', 'pl_pubdate', 'releasedate'],
#       dtype='object')

# %%
nasaexo = pd.read_csv('./Exo-Planet-Archive/nasa_exoplanets.csv')
nasaexo
# Out:
#        row                  name  light_years_from_earth     planet_mass  \
# 0        0  11 Comae Berenices b                   305.0   19.4 Jupiters
# 1        1    11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2        2       14 Andromedae b                   247.0    4.8 Jupiters
# 3        3         14 Herculis b                    59.0   4.66 Jupiters
# 4        4          16 Cygni B b                    69.0   1.78 Jupiters
# ...    ...                   ...                     ...             ...
# 4279  4279                XO-6 b                   773.0    4.4 Jupiters
# 4280  4280                XO-7 b                   764.0  0.709 Jupiters
# 4281  4281             YZ Ceti b                    12.0     0.75 Earths
# 4282  4282             YZ Ceti c                    12.0     0.98 Earths
# 4283  4283             YZ Ceti d                    12.0     1.14 Earths
#
#       stellar_magnitude  discovery_date  planet_type    planet_radius  \
# ...
